# %%
pip install oct2py
# Out:
# Collecting oct2py
#   Downloading oct2py-5.6.0-py3-none-any.whl (45 kB)
#                                               0.0/45.7 kB ? eta -:--:--
#                                               0.0/45.7 kB ? eta -:--:--
#                                               0.0/45.7 kB ? eta -:--:--
#                                               0.0/45.7 kB ? eta -:--:--
#      --------                                 10.2/45.7 kB ? eta -:--:--
#      --------                                 10.2/45.7 kB ? eta -:--:--
#      --------                                 10.2/45.7 kB ? eta -:--:--
#      --------                                 10.2/45.7 kB ? eta -:--:--
#      --------                                 10.2/45.7 kB ? eta -:--:--
#      --------                                 10.2/45.7 kB ? eta -:--:--
#      --------                                 10.2/45.7 kB ? eta -:--:--
#      --------                                 10.2/45.7 kB ? eta -:--:--
#      --------                                 10.2/45.7 kB ? eta -:--:--
#      --------                                 10.2/45.7 kB ? eta -:--:--
#      --------                                 10.2/45.7 kB ? eta -:--:--
#      --------------------------------------- 45.7/45.7 kB 66.7 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.12 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from oct2py) (1.25.1)
# Collecting octave-kernel>=0.34.0 (from oct2py)
#   Downloading octave_kernel-0.35.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: scipy>=0.17 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from oct2py) (1.11.1)
# Requirement already satisfied: ipykernel in c:\users\oscar\appdata\roaming\python\python311\site-packages (from octave-kernel>=0.34.0->oct2py) (6.25.0)
# Requirement already satisfied: jupyter-client>=4.3.0 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from octave-kernel>=0.34.0->oct2py) (8.3.0)
# Collecting metakernel>=0.24.0 (from octave-kernel>=0.34.0->oct2py)
#   Downloading metakernel-0.30.1-py3-none-any.whl (217 kB)
#                                               0.0/217.8 kB ? eta -:--:--
#                                               0.0/217.8 kB ? eta -:--:--
#                                               0.0/217.8 kB ? eta -:--:--
#                                               0.0/217.8 kB ? eta -:--:--
#                                               0.0/217.8 kB ? eta -:--:--
#                                               0.0/217.8 kB ? eta -:--:--
#                                               0.0/217.8 kB ? eta -:--:--
#                                               0.0/217.8 kB ? eta -:--:--
#                                               0.0/217.8 kB ? eta -:--:--
#                                               0.0/217.8 kB ? eta -:--:--
#                                               0.0/217.8 kB ? eta -:--:--
#      -------------------                    112.6/217.8 kB 3.3 MB/s eta 0:00:01
#      -------------------                    112.6/217.8 kB 3.3 MB/s eta 0:00:01
#      --------------------                 122.9/217.8 kB 901.1 kB/s eta 0:00:01
#      ---------------------------          163.8/217.8 kB 984.6 kB/s eta 0:00:01
#      ----------------------------         174.1/217.8 kB 876.1 kB/s eta 0:00:01
#      ---------------------------------    204.8/217.8 kB 778.2 kB/s eta 0:00:01
#      ------------------------------------ 217.8/217.8 kB 698.7 kB/s eta 0:00:00
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (5.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (25.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (6.3.2)
# Requirement already satisfied: traitlets>=5.3 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (5.9.0)
# Requirement already satisfied: jedi>=0.18 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py) (0.18.2)
# Collecting pexpect>=4.8 (from metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py)
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#                                               0.0/59.0 kB ? eta -:--:--
#      ---------------------------------------- 59.0/59.0 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: comm>=0.1.1 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (8.14.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (1.5.6)
# Requirement already satisfied: packaging in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (23.1)
# Requirement already satisfied: psutil in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (5.9.5)
# Requirement already satisfied: backcall in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.2.0)
# Requirement already satisfied: decorator in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.6.2)
# Requirement already satisfied: colorama in c:\users\oscar\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from jedi>=0.18->metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (3.9.1)
# Requirement already satisfied: pywin32>=300 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (306)
# Collecting ptyprocess>=0.5 (from pexpect>=4.8->metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: six>=1.5 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\oscar\appdata\roaming\python\python311\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\oscar\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.2.2)
# Installing collected packages: ptyprocess, pexpect, metakernel, octave-kernel, oct2py
# Successfully installed metakernel-0.30.1 oct2py-5.6.0 octave-kernel-0.35.1 pexpect-4.8.0 ptyprocess-0.7.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
import sklearn as sl
import oct2py as oclib

# %%
year_list = [1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
       2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
josb_assets_list = [101.783,90.671,81.41,77.144,82.515,84.751,88.954,108.457,133.993,186.511,231.83,
                 304.832,368.392,440.098,491.366,556.364,662.037,813.612,894.847,935.738]
mw_assets_list = [160.494,204.105,295.478,379.415,403.732,611.195,707.734,717.869,769.313,869.198,993.322,
               1123.274,1096.952,1256.467,1187.73,1232.106,1320.318,1405.952,1496.347,1555.23]

# %%
plt.figure(figsize=(24,24), dpi= 40)
plt.plot(year_list,josb_assets_list,label="Joseph A Bank",linewidth=8)
plt.plot(year_list,mw_assets_list,'g--',label="Men's Wearhouse",linewidth=8)
xtick_location = np.arange(1994,2013,4)
plt.xticks(ticks=xtick_location, rotation=0, fontsize=50, horizontalalignment='center')
plt.legend(bbox_to_anchor=(0.50, 0.95),fontsize=50)
plt.yticks(fontsize=50)
plt.grid(axis='both')
plt.xlabel('Year', fontsize = 65)
plt.ylabel('Total Assets', fontsize = 65)
# Out:
# Text(0, 0.5, 'Total Assets')

# %%
random_values = np.random.normal(1000,200,10000)
bins = np.linspace(400,1600,60)
plt.figure(figsize=(24,16), dpi= 40)
plt.hist(random_values,bins)
plt.xlabel('Total Assets', fontsize = 65)
plt.ylabel('Frequency', fontsize = 65)
plt.xticks(fontsize=50)
plt.yticks(fontsize=50)
plt.grid(axis='both')
plt.title('Histogram of Asset Values in NYSE', fontsize = 65)
# Out:
# Text(0.5, 1.0, 'Histogram of Asset Values in NYSE')

# %%
sp.stats.norm.isf(0.05,90000,10000)
# Out:
# 106448.53626951473

# %%
import pandas as pd
input_table = pd.read_csv(r"C:\Users\oscar\Downloads\sales_data.csv")
input_table.head()
# Out:
#     Order ID  Product ID  Amount (kg) Order Confirm Date  \
# 0  1005781.0   8908023.0      20000.0                NaN
# 1  1005998.0   8909373.0       6297.0                NaN
# 2  1005969.0   8908023.0      20000.0         2020-05-29
# 3  1005969.0   8908023.0      20000.0         2020-05-29
# 4        NaN         NaN          NaN                NaN
#
#   Required Delivery Date
# 0             2020-07-30
# 1             2020-07-15
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
#                                               0.0/1.4 MB ? eta -:--:--
#      ---                                      0.1/1.4 MB 3.3 MB/s eta 0:00:01
#      ------                                   0.2/1.4 MB 2.8 MB/s eta 0:00:01
#      --------------                           0.5/1.4 MB 3.8 MB/s eta 0:00:01
#      --------------------------               0.9/1.4 MB 5.1 MB/s eta 0:00:01
#      ------------------------------------     1.2/1.4 MB 5.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.1 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (1.11.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (1.25.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (1.3.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (3.7.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (1.3.1)
# Requirement already satisfied: setuptools in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from mlxtend) (65.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\oscar\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.22.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

shopping_basket = pd.read_csv(r"C:\Users\oscar\Downloads\small_dataset.csv")
shopping_basket.head()
# Out:
#    Transaction ID             ItemsPurchased
# 0               1         biscuit,bread,milk
# 1               2  biscuit,bread,cereal,milk
# 2               3                  bread,tea
# 3               4             bread,jam,milk
# 4               5                biscuit,tea

# %%
transaction_list = list(shopping_basket["ItemsPurchased"].apply(lambda t:t.split(",")))

# %%
encoder = TransactionEncoder().fit(transaction_list)

# %%
transaction_list = list(shopping_basket["ItemsPurchased"].apply(lambda t:t.split(",")))
encoder = TransactionEncoder().fit(transaction_list)
encoded_transaction_list = encoder.transform(transaction_list)
ideal_format_table = pd.DataFrame(encoded_transaction_list, columns = encoder.columns_)
ideal_format_table.head()
# Out:
#    biscuit  bread  cereal    jam   milk    tea
# 0     True   True   False  False   True  False
# 1     True   True    True  False   True  False
# 2    False   True   False  False  False   True
# 3    False   True   False   True   True  False
# 4     True  False   False  False  False   True
